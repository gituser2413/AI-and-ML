# %%
#Cropped img of Dimention x axis(150,200) and y axis(300,350)
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread("images/lenna.png")

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
cropped_image=img[150:300,200:350]

# %%
plt.imshow(cropped_image)

# %%
#Cropped the Img of Dimention 15% on all 4 sides

img = plt.imread("images/lenna.png")

# %%
startRow = int(height*1.5)
startRow = int(height*1.5)
endRow = int(height*0.5)
endCol = int(height*0.5)

cropped_image=img[startRow:startRow ,endRow:endCol]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 startRow = int(height*1.5)
#       2 startRow = int(height*1.5)
#       3 endRow = int(height*0.5)
#
# NameError: name 'height' is not defined

# %%
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(cropped_image)

# %%
#created two matrix

# %%
x=np.array([[5,6,7],[2,5,8],[8,8,9]])

# %%
y=np.array([[2,5,8],[1,9,0],[3,2,5]])

# %%
x
# Out:
# array([[5, 6, 7],
#        [2, 5, 8],
#        [8, 8, 9]])

# %%
y
# Out:
# array([[2, 5, 8],
#        [1, 9, 0],
#        [3, 2, 5]])

# %%
z= np.hstack([x,y])   #horizontalStack

# %%
z
# Out:
# array([[5, 6, 7, 2, 5, 8],
#        [2, 5, 8, 1, 9, 0],
#        [8, 8, 9, 3, 2, 5]])

# %%
z= np.vstack([x,y])   # Vertically Connected.

# %%
z
# Out:
# array([[5, 6, 7],
#        [2, 5, 8],
#        [8, 8, 9],
#        [2, 5, 8],
#        [1, 9, 0],
#        [3, 2, 5]])

# %%
#Flipped the image horizontally

# %%
flipped_horizontal =cv2.flip(img,0)

# %%
new_img = np.hstack([img,flipped_horizontal])

# %%
plt.imshow(new_img )

# %%
flipped_vertical =cv2.flip(img,0)

new_img = np.vstack([img,flipped_vertical])

plt.imshow(new_img )

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow -U
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#      ---------------------------------------- 46.2/46.2 kB 2.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/377.0 MB ? eta -:--:--
#    ---------------------------------------- 0.2/377.0 MB 6.1 MB/s eta 0:01:02
#    ---------------------------------------- 0.6/377.0 MB 7.9 MB/s eta 0:00:48
#    ---------------------------------------- 1.2/377.0 MB 9.3 MB/s eta 0:00:41
#    ---------------------------------------- 1.3/377.0 MB 8.9 MB/s eta 0:00:43
#    ---------------------------------------- 2.2/377.0 MB 10.1 MB/s eta 0:00:38
#    ---------------------------------------- 2.5/377.0 MB 10.1 MB/s eta 0:00:38
# ...

# %%
import tensorflow as tf

# %%
tf
# Out:
# <module 'tensorflow' from 'C:\\Users\\rajesh\\AppData\\Roaming\\Python\\Python311\\site-packages\\tensorflow\\__init__.py'>

# %% [markdown]
# ##### Tensor

# %%
a = tf.constant([1,2,3])
b = tf.constant([4,5,6])

print("Tensor a:",a)
print("Tensor b:",b)
# Out:
# Tensor a: tf.Tensor([1 2 3], shape=(3,), dtype=int32)
# Tensor b: tf.Tensor([4 5 6], shape=(3,), dtype=int32)

# %%
a[0]
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=1>

# %%
x = tf.constant([[1,2,3],[7,5,8]] )
y = tf.constant([[4,5],[9,0]])

print("Tensor a:",a)
print("Tensor b:",b)
# Out:
# Tensor a: tf.Tensor([1 2 3], shape=(3,), dtype=int32)
# Tensor b: tf.Tensor([4 5 6], shape=(3,), dtype=int32)

# %%
import numpy as np

# %%
np
# Out:
# <module 'numpy' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\numpy\\__init__.py'>

# %%
x = tf.constant([[1,2,3],[7,5,8]],dtype=np.int8)
y = tf.constant([[4,5],[9,0]])

print("Tensor x:",x)
print("Tensor y:",y)
# Out:
# Tensor x: tf.Tensor(
# [[1 2 3]
#  [7 5 8]], shape=(2, 3), dtype=int8)
# Tensor y: tf.Tensor(
# [[4 5]
#  [9 0]], shape=(2, 2), dtype=int32)

# %%
x = tf.constant([[1,2,3],[7,5,8],[1,8,3],[7,4,8]],dtype=np.int8)
y = tf.constant([[4,5],[9,0]])

print("Tensor x:",x)
print("Tensor y:",y)
# Out:
# Tensor x: tf.Tensor(
# [[1 2 3]
#  [7 5 8]
#  [1 8 3]
#  [7 4 8]], shape=(4, 3), dtype=int8)
# Tensor y: tf.Tensor(
# [[4 5]
#  [9 0]], shape=(2, 2), dtype=int32)

# %%
#add tensor

c=tf.add(a,b)
print("ADD: ",c)
# Out:
# ADD:  tf.Tensor([5 7 9], shape=(3,), dtype=int32)

# %%
a+b
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([5, 7, 9])>

# %%
a-b
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([-3, -3, -3])>

# %%
a.numpy()
# Out:
# array([1, 2, 3])

# %%
#Divide tensor

e=tf.divide(a,b)
print("Divide: ",e)
# Out:
# Divide:  tf.Tensor([0.25 0.4  0.5 ], shape=(3,), dtype=float64)

# %%
#multilpy tensor

f=tf.multiply(a,b)
print("Multiply: ",f)
# Out:
# Multiply:  tf.Tensor([ 4 10 18], shape=(3,), dtype=int32)

# %%
#substract tensor

d=tf.subtract(a,b)
print("substract: ",d)
# Out:
# substract:  tf.Tensor([-3 -3 -3], shape=(3,), dtype=int32)

# %%
a/b
# Out:
# <tf.Tensor: shape=(3,), dtype=float64, numpy=array([0.25, 0.4 , 0.5 ])>

# %%
b/a
# Out:
# <tf.Tensor: shape=(3,), dtype=float64, numpy=array([4. , 2.5, 2. ])>

# %%
b//a
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([4, 2, 2])>

# %%
a//b
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([0, 0, 0])>

# %%
#matrix Multiplication
a_matrix = tf.constant([[4,1],[9,7]])

b_matrix = tf.constant([[4,5],[9,0]])

g=tf.matmul(a_matrix ,b_matrix)

print("Multiplication Of matrix x:",g)
# Out:
# Multiplication Of matrix x: tf.Tensor(
# [[25 20]
#  [99 45]], shape=(2, 2), dtype=int32)

# %%
tf.add
# Out:
# <function tensorflow.python.ops.math_ops.add(x, y, name=None)>

9 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.9/38.8 MB 11.7 MB/s eta 0:00:02
#    ------------------------ --------------- 23.4/38.8 MB 11.9 MB/s eta 0:00:02
#    ------------------------ --------------- 24.0/38.8 MB 11.9 MB/s eta 0:00:02
#    ------------------------- -------------- 24.5/38.8 MB 11.9 MB/s eta 0:00:02
#    ------------------------- -------------- 24.5/38.8 MB 11.9 MB/s eta 0:00:02
#    -------------------------- ------------- 25.6/38.8 MB 11.9 MB/s eta 0:00:02
#    -------------------------- ------------- 26.2/38.8 MB 11.9 MB/s eta 0:00:02
#    --------------------------- ------------ 26.7/38.8 MB 11.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.3/38.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.8/38.8 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.4/38.8 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.9/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 29.5/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 30.0/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------- -------- 30.6/38.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 31.1/38.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 31.7/38.8 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 32.2/38.8 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 32.8/38.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.3/38.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.9/38.8 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.5/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.0/38.8 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------ --- 35.6/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.1/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.7/38.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 37.8/38.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 10.7 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.6 MB 15.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.6 MB 13.3 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.6 MB 12.8 MB/s eta 0:00:01
#    --------------------------------- ------ 2.2/2.6 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 11.6 MB/s eta 0:00:00
# Downloading scikit_image-0.24.0-cp311-cp311-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.6/12.8 MB 12.4 MB/s eta 0:00:01
#    --- ------------------------------------ 1.1/12.8 MB 12.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.7/12.8 MB 11.9 MB/s eta 0:00:01
#    ------- -------------------------------- 2.3/12.8 MB 12.0 MB/s eta 0:00:01
#    -------- ------------------------------- 2.8/12.8 MB 11.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.4/12.8 MB 11.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.9/12.8 MB 11.9 MB/s eta 0:00:01
#    ------------- -------------------------- 4.5/12.8 MB 11.9 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.8 MB 11.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.8 MB 11.9 MB/s eta 0:00:01
#    ------------------- -------------------- 6.1/12.8 MB 11.9 MB/s eta 0:00:01
#    -------------------- ------------------- 6.7/12.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.2/12.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------ --------------- 7.8/12.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------- -------------- 8.3/12.8 MB 11.9 MB/s eta 0:00:01
#    --------------------------- ------------ 8.9/12.8 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.5/12.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 10.6/12.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.1/12.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 11.7/12.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 12.2/12.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 11.5 MB/s eta 0:00:00
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Installing collected packages: pillow, opencv-python, lazy-loader, scikit-image
# Successfully installed lazy-loader-0.4 opencv-python-4.10.0.84 pillow-10.4.0 scikit-image-0.24.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
#https://mitu.co.in/dataset

# %%
impory os
# Out:
#   Cell In[3], line 1
#     impory os
#            ^
# SyntaxError: invalid syntax

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rajesh'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rajesh'

# %%
img1 = cv2.imread("images/lenna.png")

# %%
cv2.imshow("First Img",img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### using MatPlotLib

# %%
img_pit = plt.imread("images/lenna.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 img_pit = plt.imread("images/lenna.png")
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
img_pit = plt.imread("images/lenna.png")

# %%
plt.imshow(img_pit)

# %%
from skimage import io

# %%
img_ski = io.imread("images/lenna.png")

# %%
plt.imshow(img_ski)

# %% [markdown]
# ##### Using PILLOW

# %%
from PIL import Images
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from PIL import Images
#
# ImportError: cannot import name 'Images' from 'PIL' (C:\Users\rajesh\AppData\Roaming\Python\Python311\site-packages\PIL\__init__.py)

# %%
from PIL import Image

# %%
img_pil = Image.open("images/lenna.png")

# %% [markdown]
# ##### TensorFlow

# %%
import tensorflow as tf

# %%
img_tf = tf.io.read_file("images/lenna.png")
img_tf =tf.image.decode_image(img_tf,channels = 3)

# %%
plt.imshow(img_tf)

# %%
type(img1)
# Out:
# numpy.ndarray

# %%
img1
# Out:
# array([[[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        ...,
#
#        [[ 60,  18,  84],
#         [ 60,  18,  84],
#         [ 58,  27,  92],
#         ...,
#         [ 84,  73, 173],
#         [ 76,  68, 172],
#         [ 79,  62, 177]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]]], dtype=uint8)

# %%
img1.shape
# Out:
# (512, 512, 3)

# %%
img_pit.shape
# Out:
# (512, 512, 3)

# %%
img_ski.shape
# Out:
# (512, 512, 3)

# %%
img_tf.shape
# Out:
# TensorShape([512, 512, 3])

# %%
img_pil.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 img_pil.shape
#
# AttributeError: 'PngImageFile' object has no attribute 'shape'

# %%
type(img1),type(img_pit)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
img_pit
# Out:
# array([[[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        ...,
#
#        [[0.32941177, 0.07058824, 0.23529412],
#         [0.32941177, 0.07058824, 0.23529412],
#         [0.36078432, 0.10588235, 0.22745098],
#         ...,
#         [0.6784314 , 0.28627452, 0.32941177],
#         [0.6745098 , 0.26666668, 0.29803923],
#         [0.69411767, 0.24313726, 0.30980393]],
#
#        [[0.32156864, 0.08627451, 0.22352941],
#         [0.32156864, 0.08627451, 0.22352941],
#         [0.3764706 , 0.1254902 , 0.24313726],
#         ...,
#         [0.7019608 , 0.27450982, 0.30980393],
#         [0.70980394, 0.2784314 , 0.31764707],
#         [0.7254902 , 0.2901961 , 0.31764707]],
#
#        [[0.32156864, 0.08627451, 0.22352941],
#         [0.32156864, 0.08627451, 0.22352941],
#         [0.3764706 , 0.1254902 , 0.24313726],
#         ...,
#         [0.7019608 , 0.27450982, 0.30980393],
#         [0.70980394, 0.2784314 , 0.31764707],
#         [0.7254902 , 0.2901961 , 0.31764707]]], dtype=float32)

# %%
import numpy as np

# %%
img_new = np.zeros([100,100])

# %%
plt.imshow(img_new)

# %%
plt.imshow(img_new,cmap = "gray")

# %%
img_new[34,57] = 0.5

# %%
plt.imshow(img_new,cmap = "gray")

# %%
img_new[34]=1

# %%
plt.imshow(img_new,cmap = "gray")

# %%
np.random.randint(12,78)
# Out:
# 34

# %%
img_new = np.zeros([100,100],dtype = np.uint8)

# %%
for i in range(100):
    for j in range(100):
        img_new[i,j] = np.random.randint(0,255)

# %%
plt.imshow(img_new ,cmap = "gray")

# %% [markdown]
# ##### Grayscale Img

# %%
img_gray = cv2.imread("images/lenna.png",0)

# %%
img_gray.shape
# Out:
# (512, 512)

# %%
plt.imshow(img_gray ,cmap = "gray")

# %%
img_gray = cv2.imread("images/lenna.png",1)

# %%
plt.imshow(img_gray ,cmap = "gray")

# %%
img_pit.shape
# Out:
# (512, 512, 3)

# %%
img_pit[[0:511][1,:511]]
# Out:
#   Cell In[68], line 1
#     img_pit[[0:511][1,:511]]
#               ^
# SyntaxError: invalid syntax

# %%
img_pit([[0:511],[1:511],3])
# Out:
#   Cell In[69], line 1
#     img_pit([[0:511],[1:511],3])
#                ^
# SyntaxError: invalid syntax

# %%
img_pit([:,:,0])
# Out:
#   Cell In[70], line 1
#     img_pit([:,:,0])
#              ^
# SyntaxError: invalid syntax

# %%
img_pit[:,:,0]
# Out:
# array([[0.8862745 , 0.8862745 , 0.8745098 , ..., 0.9019608 , 0.8666667 ,
#         0.78431374],
#        [0.8862745 , 0.8862745 , 0.8745098 , ..., 0.9019608 , 0.8666667 ,
#         0.78431374],
#        [0.8862745 , 0.8862745 , 0.8745098 , ..., 0.9019608 , 0.8666667 ,
#         0.78431374],
#        ...,
#        [0.32941177, 0.32941177, 0.36078432, ..., 0.6784314 , 0.6745098 ,
#         0.69411767],
#        [0.32156864, 0.32156864, 0.3764706 , ..., 0.7019608 , 0.70980394,
#         0.7254902 ],
#        [0.32156864, 0.32156864, 0.3764706 , ..., 0.7019608 , 0.70980394,
#         0.7254902 ]], dtype=float32)

# %%
r=img_pit[:,:,0]

# %%
g=img_pit[:,:,0]
b=img_pit[:,:,0]

# %%
r.shape,g.shape,b.shape
# Out:
# ((512, 512), (512, 512), (512, 512))

# %%
g=img_pit[:,:,1]
b=img_pit[:,:,2]

# %%
r.shape,g.shape,b.shape
# Out:
# ((512, 512), (512, 512), (512, 512))

# %%
plt.subplot(1,3,1)
plt.imshow(r, cmap = "gray")
plt.subplot(1,3,2)
plt.imshow(r, cmap = "gray")
plt.subplot(1,3,3)
plt.imshow(r, cmap = "gray")

# %%
plt.subplot(1,3,1)
plt.imshow(r, cmap = "Reds")
plt.subplot(1,3,2)
plt.imshow(r, cmap = "Greens")
plt.subplot(1,3,3)
plt.imshow(r, cmap = "Blues")

# %%
new_img =(r+g+b)/3

# %%
plt.imshow(r, cmap = "gray")

# %%
plt.subplot(1,2,1)
plt.title("IMG Using cv2")
plt.imshow(img1)
plt.subplot(1,2,2)
plt.title("IMG Using MatPlotlib")
plt.imshow(img_pit)

# %%
img2 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
plt.subplot(1,2,1)
plt.title("IMG Using cv2")
plt.imshow(img2)
plt.subplot(1,2,2)
plt.title("IMG Using MatPlotlib")
plt.imshow(img_pit)

# %%
import sys

# %%
sys.getsizeof(img1)
# Out:
# 786576

# %%
sys.getsizeof(img_pit)
# Out:
# 3145872

# %%
sys.getsizeof(img2)
# Out:
# 786576
